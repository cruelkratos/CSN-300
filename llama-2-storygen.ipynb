# %%
# Step 1: Install required libraries
# !pip install -q transformers accelerate peft bitsandbytes datasets

# Step 2: Authenticate with Hugging Face
from huggingface_hub import login
login("your-access-token")

# Step 3: Import necessary components
import torch
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    DataCollatorForLanguageModeling,
    TrainingArguments,
    Trainer,
    TrainerCallback  # Import TrainerCallback here
)
from peft import LoraConfig, get_peft_model
from datasets import Dataset
import time

# Step 4: Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-chat-hf")
tokenizer.pad_token = tokenizer.eos_token

# Step 5: Prepare dataset
def chunk_text(text, chunk_size=512):
    return [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]

with open("/kaggle/input/harry-potter/HarryPotter4Books.txt", "r") as f:
    text = f.read()

chunks = chunk_text(text)
dataset = Dataset.from_dict({"text": chunks})

def tokenize_function(examples):
    return tokenizer(examples["text"], truncation=True, max_length=512)

tokenized_dataset = dataset.map(tokenize_function, batched=True, remove_columns=["text"])

# Step 6: Configure model with PEFT
model = AutoModelForCausalLM.from_pretrained(
    "meta-llama/Llama-2-7b-chat-hf",
    device_map="auto",
    load_in_4bit=True,
    torch_dtype=torch.float16
)

peft_config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()

# Step 7: Create custom callback for periodic generation
class StoryGeneratorCallback(TrainerCallback):  # Now TrainerCallback is defined
    def __init__(self, tokenizer, interval=300):  # 300 seconds = 5 minutes
        self.tokenizer = tokenizer
        self.interval = interval
        self.last_generation = time.time()
        self.prompts = [
            "Harry Potter and Hermione Granger were exploring",
            "Suddenly, the Dark Mark appeared",
            "In the Great Hall, Dumbledore announced",
            "Ron Weasley dropped his wand when",
            "A mysterious package arrived at Hogwarts containing"
        ]
    
    def on_step_end(self, args, state, control, **kwargs):
        if time.time() - self.last_generation > self.interval:
            self.last_generation = time.time()
            model = kwargs["model"]
            prompt = self.prompts[state.global_step % len(self.prompts)]
            
            # Generate story
            inputs = self.tokenizer(prompt, return_tensors="pt").to(model.device)
            with torch.no_grad():
                outputs = model.generate(
                    **inputs,
                    max_new_tokens=150,
                    temperature=0.7,
                    top_p=0.9,
                    do_sample=True
                )
            
            story = self.tokenizer.decode(outputs[0], skip_special_tokens=True)
            print(f"\n\n--- Generated Story at Step {state.global_step} ---")
            print(story)
            print("\n" + "="*50 + "\n")
        return control

# Step 8: Set up training configuration
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

training_args = TrainingArguments(
    output_dir="./hp_storyteller",
    num_train_epochs=3,
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    learning_rate=2e-4,
    weight_decay=0.001,
    warmup_ratio=0.05,
    fp16=True,
    logging_steps=50,
    optim="paged_adamw_8bit",
    report_to="none",
    save_strategy="steps",
    save_steps=500
)

# Step 9: Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    data_collator=data_collator,
    callbacks=[StoryGeneratorCallback(tokenizer)]
)

# Step 10: Start training
print("Starting training...")
trainer.train()

# Step 11: Save the final model
model.save_pretrained("./hp_storyteller_final")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 22.3 MB/s eta 0:00:00:00:0100:01
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Map:   0%|          | 0/5172 [00:00<?, ? examples/s]
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# trainable params: 4,194,304 || all params: 6,742,609,920 || trainable%: 0.0622
# Starting training...
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py:451: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
#     <div>
#
#       <progress value='1938' max='1938' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1938/1938 2:57:41, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>10.668600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>9.148300</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>9.021200</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>8.886900</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>8.834100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>8.771000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>8.729800</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>8.708300</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>8.686000</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>8.538900</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>8.587100</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>8.591200</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>8.497900</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>8.280100</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>8.312000</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>8.213100</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>8.322400</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>8.248400</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>8.251100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>8.228100</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>8.233000</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>8.280000</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>8.191200</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>8.176000</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>8.171500</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>8.043900</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>7.886000</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>7.770300</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>7.887300</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>7.889400</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>7.877200</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>7.763300</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>7.817400</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>7.878200</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>7.917300</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>7.854700</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>7.878100</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>7.784100</td>
#     </tr>
#   </tbody>
# </table><p>
# --- Generated Story at Step 60 ---
# Harry Potter and Hermione Granger were exploring the forest, looking for the entrance to the Chamber. Harry was still dressed in his school robes, but Hermione was wearing a long, billowy cloak to keep warm.
# "I can't believe we're doing this," Harry said, his voice hushed. "We're not supposed to be in the forest. I don't want to get in trouble."
# "We have to find the Chamber," Hermione said firmly. "We have to get the Philosopher's Stone."
# "But it's dangerous," Harry said. "I don't want to get caught. We'll be expelled."
# "We have to do it," Hermione said. "
#
# ==================================================
#
#
#
# --- Generated Story at Step 115 ---
# Harry Potter and Hermione Granger were exploring the
#  Harry Potter and the Goblet of Fire 31
# corridors. They were in the process of
# discovering that the giant, filthy, and very
# angry giant, Rubeus Hagrid, was an
# unlikely friend of theirs.
#
# "Dumbledore said I could come and get
# you," Hagrid was saying to Harry and
# Hermione, his face twisted in a grimace of
# determination. "I've got to take you to the
# Forbidden Forest. Come on, you two.
#
# "But why?" said Hermione, looking at the
# giant with dismay.
#
# "That
#
# ==================================================
#
#
#
# --- Generated Story at Step 170 ---
# Harry Potter and Hermione Granger were exploring the
# laboratory as they walked. They were in a large room full of strange
# equipment, which was now covered with a thick layer of dust. The
# windows were shut and curtained, and the only light came from the
# candles on the tables.
#
# "I don't know what you're looking for, but I don't think it's here,"
# said Hermione, shaking her head as she examined a shelf full of ancient
# books.
#
# "There's a book missing," said Harry, staring at a shelf that was
# normally full of books.
#
# "What book?"
#
# "The one with the red
#
# ==================================================
#
#
#
# --- Generated Story at Step 225 ---
# Harry Potter and Hermione Granger were exploring the
# Harry Potter and Hermione Granger were exploring the wood. The night was
# cold and dark, and they had just turned off the main path to walk down a
# narrower one that ran between the trees.
#
#
# ==================================================
#
#
#
# --- Generated Story at Step 940 ---
# Harry Potter and Hermione Granger were exploring the dungeons of Hogwarts, in search of the last piece of the Dark Lord's memory.  They had been following the narrow, winding tunnels for what felt like hours, and the air was growing heavier and heavier.  They had heard the distant rumble of a voice, but the echoes were growing fainter.  Now the air was so heavy they could barely move.  Harry's heart was thudding, and he had the feeling that they were being watched.
#
# "Don't worry," Harry whispered to Hermione. "It's probably just the Slytherins.  Come on, we'll get out of here.  We
#
# ==================================================
#
#
#
# --- Generated Story at Step 995 ---
# Harry Potter and Hermione Granger were exploring the
# staircase leading up to the second floor when they heard a loud noise.
#
# Harry and Hermione crept up the stairs, but there was no sign of
# Hagrid, Malfoy, or the monkey.
#
# "I don't think it's in here," said Harry, looking at the door that led
# into the girls' dormitory.
#
# "I've got an idea," said Hermione, "it might be in the library."
#
# They crept along the corridor, their ears straining for any noise.
#
# "It's not in the library either," said Harry, "it's not as if it's
#
# ==================================================
#
#
#
# --- Generated Story at Step 1050 ---
# Harry Potter and Hermione Granger were exploring the
# They were walking along a long, dark, narrow passage, Harry clutching his
# stuffed owl, Snowy, and Hermione clutching a large pile of books.
#
# "We're on the right floor," said Harry. "I can hear the sound of a
# waterfall."
#
# "Look," said Hermione, pointing upwards. "There's a window. Let's go
# up there."
#
# They climbed the stone spiral staircase to the first floor, where they
# found a long gallery with a window at the far end.
#
# "This is it," said Hermione, who was staring at the books she had
# br
#
# ==================================================
#
#
#
# --- Generated Story at Step 1105 ---
# Harry Potter and Hermione Granger were exploring the
# thirteenth floor.
#
# "So, what's the point of a ghost?" Harry muttered, looking around
# him.
#
# "Well, it can't have done anything wrong, can it?" said Hermione. "It
# can't have died in the school, it'd be all over the Daily Prophet,
# wouldn't it?"
#
# "But it doesn't seem to care what we're doing," said Harry. "It's just
# there, wandering around, watching us. It's like a -- a spy."
#
# "A spy?" said Hermione, looking up at him. "But what could it
#
# ==================================================
#
#
#
# --- Generated Story at Step 1160 ---
# Harry Potter and Hermione Granger were exploring
# the castle at night, and, as always, they had no idea what they were
# looking for.
#
# "Harry, I think I've found something," Hermione called out from
# somewhere in the shadows.
#
# "Oh, come on!" Harry muttered, as he hastened after her. "Can't we
# just do something else?"
#
# They were standing at the top of a flight of stone stairs, the torches
# behind them making the shadows dance on the walls. Hermione was
# leaning over a large stone door, fiddling with a keyhole.
#
# "What is it?" said Harry, bending over her.
#
# "I
#
# ==================================================
#
#
#
# --- Generated Story at Step 1215 ---
# Harry Potter and Hermione Granger were exploring the
# Hogwarts grounds on their way back to the castle. It was a bright,
# sunny day, but there was a cold wind blowing. Harry and Hermione had
# just been to the library to check the books on Dark Magic.
#
# "I'm not sure what's going on," Harry said, shivering slightly. "I
# mean, I know Dumbledore thinks the Chamber of Secrets's been opened
# again, but --"
#
# "It's not just the attacks on the Muggle-born students," said Hermione,
# shaking her head. "It's the ghosts too. I saw a ghost in the library
# y
#
# ==================================================
#
#
#
# --- Generated Story at Step 1270 ---
# "This is going to be the best day ever," Harry said, shaking his head
# in disbelief.
#
# "I don't know, I don't like it at all," said Hermione. "What if
# Snape's right? What if the Chamber really has been opened again?"
#
# "Snape's always saying things like that to try and scare us," said Harry.
# "We're not scared, though."
#
# "But what if we should find the Chamber?" said Hermione, her eyes
# wide with fright. "What if
#
# ==================================================
#
#
#
# --- Generated Story at Step 1655 ---
# Harry Potter and Hermione Granger were exploring the
# housemouse-infested attic, where they had found a cupboard full of old
# brooms, when a squeak from the cupboard floor made Harry jump.
#
# "What's that?"
#
# "Dunno," said Harry.
#
# The squeak came again.
#
# "I think --"
#
# "What?"
#
# "I think it's moving."
#
# "It's a mouse."
#
# "What?"
#
# "It's a mouse."
#
# Harry and Hermione moved closer to the cupboard and saw that a tiny
# mouse was sitting on the bottom, squeaking loudly.
#
# "It's
#
# ==================================================
#
#
#
# --- Generated Story at Step 1710 ---
# Harry Potter and Hermione Granger were exploring the
# thirteenth floor, a warren of dingy little rooms.
#
# "I've found something!" Hermione cried, waving her hand at Harry, who
# was following her down a narrow corridor. "Look!"
#
# She held out a little leather-bound book to Harry, who sat down on the
# edge of a bed to look at it.
#
# "It's an old wizard's diary," said Hermione, flipping the pages. "There's
# nothing in it, except a list of all the things he wants to do before he
# dies."
#
# Harry flipped through the pages.
#
# "This is his
#
# ==================================================
#
#
#
# --- Generated Story at Step 1765 ---
# Harry Potter and Hermione Granger were exploring the
# Harry and Hermione sank into the darkness. Harry was
#
# *147*
#
# shivering; Hermione held his hand. He couldn't help staring at the
# darkness ahead. It seemed to be alive. He had the strangest
# feeling that it was watching them, waiting to pounce.
#
# "Hurry up," said Hermione in a whisper. "We've got to get back to
# Gryffindor before anyone notices we're gone."
#
# "But what if the dementors come?"
#
# "They won't," said Hermione confidently. "They don't come in
# these t
#
# ==================================================
#
#
#
# --- Generated Story at Step 1820 ---
# Harry Potter and Hermione Granger were exploring the
# thirteenth floor, and they were now making their way through
# dusty storerooms toward the hidden entrance to the library.
#
# "What's that?" said Harry suddenly.
#
# "What?" said Hermione, looking around.
#
# "That noise," said Harry, pointing.
#
# They had just passed a door, and there was a loud banging noise from
# behind it.
#
# "Probably just a ghost," said Hermione.
#
# "It sounds like a door slamming," said Harry. "Let's go and see."
#
# They pushed open the door, which was locked. It had been slammed shut
# from the other side.
#
#
# ==================================================
#
#
#
# --- Generated Story at Step 1875 ---
# Harry Potter and Hermione Granger were exploring the
# thought of a dragon on their own.
#
# "The most important thing," said Dumbledore, "is not to be a dragon.
# Those of you who are not dragons are the only ones who have a chance
# of understanding what dragons really are."
#
# He pointed his wand at a large, green, writhing shape in the middle of
# the room.
#
# "This is the egg of a Chinese Fireball. It was sent to me by an old
# friend, and I am sure it will hatch tonight."
#
# He pointed his wand at the egg, which suddenly began to shake and
# wobble.
#
# "The egg is trying to
#
# ==================================================
#
#
#
# --- Generated Story at Step 1930 ---
# Harry Potter and Hermione Granger were exploring the
# chamber.
#
# Harry had a sudden thought. He seized Hermione's arm and pulled her aside.
#
# "Quick, look at this!"
#
# He had just noticed something odd.
#
# "Hermione, I think the spiders' webs are made of silver thread!"
#
# "Oh, I can't see them at all!" said Hermione, squinting into the darkness.
#
# "Look, it's shining in this torchlight!"
#
# "It must be the light reflecting off their eyes!" said Hermione, squinting
# again. "Let's get out of here, we'll have to come back for
#
# ==================================================

# %%
def generate_story(prompt, max_new_tokens=210, temperature=0.7, top_p=0.9):
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            temperature=temperature,
            top_p=top_p,
            do_sample=True
        )
    
    story = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return story

# %%
print(generate_story("harry was running along a river"))
print("\n"*20)
print(generate_story("once there lived and evil wizard sam"))
print("\n"*20)
print(generate_story("hermoine found ron near a well fighting a monster"))
# Out:
# harry was running along a riverbank, and the
# cottage was in sight.
#
# "Come on, Harry, quick!"
#
# "What's going on?"
#
# "You don't know? You must have been dreaming!"
#
# "Dreaming? What about the dementor?"
#
# "The dementor?"
#
# "I was at the Quidditch World Cup, and it came out of nowhere -"
#
# "No, Harry, you weren't - you were in bed in Gryffindor Tower, and
# you'd just woken up -"
#
# "I know I was in bed! But I must've been dreaming, because -"
#
# "No, you weren't dreaming!"
#
# "How can you tell? What's going on?"
#
# "You'll see in a minute! Come on!"
#
# Harry had a feeling that his head was going to burst with questions,
# but he
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# once there lived and evil wizard sammeth
# sorcerer. He used to torture and kill people here. And he left behind
# something of his. A spellbook. I have it with me. And I have been
# trying to learn it. I've been trying to become the new Lord Voldemort.
#
# "But I couldn't. I didn't understand the spells. I couldn't even do the
#  simplest thing - turn myself into an animal. I couldn't even do that
# when I was young, when I was healthy and strong. But now I am old and
# weak and I need help. I need a body. I need a body to go out there and
# find my followers, and to kill those who are trying to stop me from
# becoming the new Lord Voldemort.
#
# "And that is why I need you, Harry Potter. You are the only one who
# can help me, because you are the only one who has beaten me.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hermoine found ron near a well fighting a monster with a
# handful of his own hair.
#
# "I've been trying to get rid of it for hours," Ron told Hermione,
# wiping sweat from his face with a towel. "It won't go into the trunk,
# it's too big, and I can't get it into the pockets, it's too long, and
# I've tried hanging it around my neck, but it won't stay there, it's
# too thick."
#
# "What's it?"
#
# "I don't know," Ron panted. "It looks like a rat, but it's got a
# huge head. It's not hurting me, but it's been pulling at my hair
# since dawn. I've got to get rid of it, I can't go to the ball with
# this. I don't know what's going to happen if it gets loose, I'

# %%
merged_model = model.merge_and_unload()

# Save full model
merged_model.save_pretrained("./hp_full_model")
tokenizer.save_pretrained("./hp_full_model")
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora/bnb.py:355: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# ('./hp_full_model/tokenizer_config.json',
#  './hp_full_model/special_tokens_map.json',
#  './hp_full_model/tokenizer.model',
#  './hp_full_model/added_tokens.json',
#  './hp_full_model/tokenizer.json')
